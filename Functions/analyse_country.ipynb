# %%
import pandas as pd
pd.set_option('display.max_rows', None) # code to not truncate dataframe when it is displayed

df = pd.read_csv("../Resources/Data_Clean_Cases.csv")

df.head()
# Out:
#    Unnamed: 0 iso_code continent     location        date  total_cases  \
# 0           0      AFG      Asia  Afghanistan  2020-02-24          5.0
# 1           1      AFG      Asia  Afghanistan  2020-02-25          5.0
# 2           2      AFG      Asia  Afghanistan  2020-02-26          5.0
# 3           3      AFG      Asia  Afghanistan  2020-02-27          5.0
# 4           4      AFG      Asia  Afghanistan  2020-02-28          5.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        5.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# ...

# %%
df.groupby('location').max()
# Out:
# C:\Users\walto\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.
#                                   Unnamed: 0  iso_code      continent  \
# location
# Afghanistan                              604       AFG           Asia
# Albania                                 1824       ALB         Europe
# Algeria                                 2428       DZA         Africa
# Andorra                                 3026       AND         Europe
# Angola                                  3606       AGO         Africa
# Antigua and Barbuda                     4447       ATG  North America
# Argentina                               5106       ARG  South America
# ...

# %%
analyse_country(df,'new_cases','new_deaths')

# for country in countries:
#     print('country')
# Out:
#                             countries  R_Squared
# 180                           Vanuatu   1.000000
# 166                          Tanzania   0.998662
# 42                               Cuba   0.945527
# 95                            Lesotho   0.907939
# 167                          Thailand   0.895497
# 36                           Colombia   0.870927
# 13                         Bangladesh   0.862553
# 178                           Uruguay   0.840167
# 29                           Cameroon   0.838658
# 128                         Palestine   0.838546
# 181                         Venezuela   0.837726
# 103                          Malaysia   0.837456
# 39                         Costa Rica   0.813025
# 179                        Uzbekistan   0.772920
# 147                            Serbia   0.772532
# 86                             Jordan   0.771635
# 10                         Azerbaijan   0.766901
# 116                           Myanmar   0.764308
# ...

# %%
def analyse_country(df,col1,col2):
    import pandas as pd
    import scipy.stats as sts
    
    countries = df['location'].unique()
    r_squared = []
    for country in countries:
        temp_df = df.loc[df['location']==country]
        temp_df = temp_df [[col1,col2]]
        temp_df = temp_df.dropna()
        
        # Perform a linear regression on x_value vs. y_value
        (slope, intercept, rvalue, pvalue, stderr) = sts.linregress(temp_df[col1], temp_df[col2])        
        
        r_squared.append(rvalue**2)
        
    analyse_df = pd.DataFrame({'countries':countries,'R_Squared':r_squared})
    analyse_df = analyse_df.sort_values(by='R_Squared',ascending = False)
    
    
    return analyse_df
